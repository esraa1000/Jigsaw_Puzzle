# %% [markdown]
# <a href="https://colab.research.google.com/github/esraa1000/Jigsaw_Puzzle/blob/main/milestone1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/esraa1000/Jigsaw_Puzzle
# Out:
# Cloning into 'Jigsaw_Puzzle'...
# remote: Enumerating objects: 461, done.
# remote: Counting objects: 100% (461/461), done.
# remote: Compressing objects: 100% (457/457), done.
# remote: Total 461 (delta 2), reused 461 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (461/461), 40.09 MiB | 12.81 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls Jigsaw_Puzzle
# Out:
# dataset  dataset.zip  jigsaw_puzzle.ipynb  README.md

# %%
# !ls Jigsaw_Puzzle/dataset
# Out:
# correct  puzzle_2x2  puzzle_4x4  puzzle_8x8

# %%
import cv2
import matplotlib.pyplot as plt

img_path = "/content/Jigsaw_Puzzle/dataset/puzzle_2x2/7.jpg"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))
